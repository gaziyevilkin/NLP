# %%
# !pip install twint 
# !pip install nest_asyncio

# %%
import twint
import nest_asyncio 
nest_asyncio.apply()

# %%
c = twint.Config()
c.Lang = 'und'
c.Custom["tweet"]=["id","date","time","tweet","hashtags","cashtags","retweets_count","likes_count","location"]
c.Search = "#tesla"
c.Since = "2018-01-01"
c.Until = "2022-01-30"
c.Limit = 500
c.Pandas = True
c.Pandas_clean = True

c.Show_hashtags = True
c.Show_cashtags = True

# %%
twint.run.Search(c)
# Out:
# 1487576283466846210 2022-01-30 02:59:58 +0300 <ali__bahrami> with coming full self-driving (FSD) systems, automotive cyber security will gain a lot of attentions! As if the system being breached....civilian safety is at stake! many SW job positions will be opened soon for ex-hacker! :D #FSD #Tesla #ADAS #EV  https://t.co/DCwZLCsM8l FSD,Tesla,ADAS,EV
# 1487575833569021952 2022-01-30 02:58:11 +0300 <LSydneyFisher> #Tesla  I just published Nikola Tesla, The Visionary: When Genius Meets the Supernatural  https://t.co/nNQjjZov9n Tesla
# 1487575801751031811 2022-01-30 02:58:03 +0300 <mechack_kainda> Really happy to see @RobinhoodApp wallets being deployed! Specifically for what this means to the #dogecoin community. Hopefully this step is what's needed for @elonmusk and #Tesla to start accepting for vehicles cuz your boy wants a plaid model X 😅 dogecoin,Tesla
# ...

# %%
twint.storage.panda.Tweets_df.head()
# Out:
#                     id      conversation_id    created_at  \
# 0  1487576283466846210  1487576283466846210  1.643501e+12
# 1  1487575833569021952  1487575833569021952  1.643501e+12
# 2  1487575801751031811  1487575801751031811  1.643501e+12
# 3  1487575622172000266  1487575622172000266  1.643501e+12
# 4  1487575377681653760  1487575377681653760  1.643501e+12
#
#                   date timezone place  \
# 0  2022-01-30 02:59:58    +0300
# 1  2022-01-30 02:58:11    +0300
# 2  2022-01-30 02:58:03    +0300
# 3  2022-01-30 02:57:20    +0300
# 4  2022-01-30 02:56:22    +0300
#
#                                                tweet language  \
# 0  with coming full self-driving (FSD) systems, a...       en
# 1  #Tesla  I just published Nikola Tesla, The Vis...       en
# 2  Really happy to see @RobinhoodApp wallets bein...       en
# 3  FLASHBACK 🔊: Mad Money Jim Cramer Says Sell Te...       en
# 4  2 days ago marked my 1 year of owning Model 3....       en
#
# ...
